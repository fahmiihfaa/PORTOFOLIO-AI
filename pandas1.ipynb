# %%
import pandas as pd
import numpy as np

url = '/content/bts_videos.csv';
df = pd.read_csv(url)

display(df) #menampilkan tabel
# Out:
#                                                  title          published_at  \
# 0    정국 (Jung Kook) ‘3D (feat. Jack Harlow)’ Promot...  2023-12-28T10:00:02Z
# 1    'BTS Monuments: Beyond The Star' EP. 5 & 6 Pre...  2023-12-28T01:00:02Z
# 2    [#슈취타] 동갑내기 #IU & #슈가 다음 콜라보 당장 진행시켜‼️ - EP.24...  2023-12-26T13:48:40Z
# 3                            [슈취타] EP.24 SUGA with 아이유  2023-12-26T13:00:11Z
# 4    [EPISODE] j-hope @ Dick Clark’s New Year's Roc...  2023-12-26T11:00:04Z
# ..                                                 ...                   ...
# 501  [BANGTAN BOMB] '고민보다 GO (GOGO)' Dance Practice...  2017-10-27T13:00:00Z
# 502            [EPISODE] BTS (방탄소년단) 'DNA' MV Shooting  2017-10-04T07:00:02Z
# 503    [CHOREOGRAPHY] BTS (방탄소년단) 'DNA' Dance Practice  2017-09-24T12:50:12Z
# 504  [BANGTAN BOMB] BTS 'DNA' MV REAL reaction @6:0...  2017-09-20T09:00:02Z
# 505  [CHOREOGRAPHY] BTS (방탄소년단) '좋아요 Part 2' Dance ...  2017-06-07T15:00:00Z
#
#      duration view_count
# ...

# %%
df.head(5) #menampilkan 5 tabel teratas
# Out:
#                                                title          published_at  \
# 0  정국 (Jung Kook) ‘3D (feat. Jack Harlow)’ Promot...  2023-12-28T10:00:02Z
# 1  'BTS Monuments: Beyond The Star' EP. 5 & 6 Pre...  2023-12-28T01:00:02Z
# 2  [#슈취타] 동갑내기 #IU & #슈가 다음 콜라보 당장 진행시켜‼️ - EP.24...  2023-12-26T13:48:40Z
# 3                          [슈취타] EP.24 SUGA with 아이유  2023-12-26T13:00:11Z
# 4  [EPISODE] j-hope @ Dick Clark’s New Year's Roc...  2023-12-26T11:00:04Z
#
#    duration view_count
# 0  PT13M47S    1362507
# 1   PT1M11S     528520
# 2     PT58S     452571
# 3  PT43M51S    2980578
# 4  PT17M54S     770616
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 49800 (\N{HANGUL SYLLABLE SYU}) missing from current font.
#   plt.savefig(
# ...

# %%
df.tail(5) #menampilkan 5 tabel terbawah
# Out:
#                                                  title          published_at  \
# 501  [BANGTAN BOMB] '고민보다 GO (GOGO)' Dance Practice...  2017-10-27T13:00:00Z
# 502            [EPISODE] BTS (방탄소년단) 'DNA' MV Shooting  2017-10-04T07:00:02Z
# 503    [CHOREOGRAPHY] BTS (방탄소년단) 'DNA' Dance Practice  2017-09-24T12:50:12Z
# 504  [BANGTAN BOMB] BTS 'DNA' MV REAL reaction @6:0...  2017-09-20T09:00:02Z
# 505  [CHOREOGRAPHY] BTS (방탄소년단) '좋아요 Part 2' Dance ...  2017-06-07T15:00:00Z
#
#     duration view_count
# 501  PT5M50S  239519934
# 502  PT3M49S   14943397
# 503  PT3M45S   59638206
# 504  PT4M52S   34857686
# 505  PT3M54S   26051315

# %%
df[20:50] #menampilkan tabel dari 20-50
# Out:
#                                                 title          published_at  \
# 20                      SUGA | Agust D 'Road to ARMY'  2023-04-23T12:00:04Z
# 21  Agust D '대취타' Live Clip (full ver.) | SUGA: Ro...  2023-04-23T08:59:59Z
# 22                                  [슈취타] EP.9 TEASER  2023-04-17T13:00:02Z
# 23  [BANGTAN BOMB] Jinny's Kitchen Press Conferenc...  2023-04-13T10:00:05Z
# 24                       [슈취타] EP.8 SUGA with 연준 & 태현  2023-04-11T13:00:08Z
# 25  [EPISODE] 지민 (Jimin) Choreography Practice Ske...  2023-04-05T10:00:07Z
# 26                                  [슈취타] EP.8 TEASER  2023-04-03T13:00:04Z
# 27  Baby, 있어줘 오늘까지만💜 #LikeCrazy #지민 #Jimin #Jimin_...  2023-03-29T12:00:27Z
# 28  'j-hope IN THE BOX' Commentary Trailer (Only o...  2023-03-28T08:00:05Z
# 29                            [슈취타] EP.7 SUGA with 지민  2023-03-27T13:00:11Z
# 30  [EPISODE] 지민 (Jimin) ‘Set Me Free Pt.2’ MV Sho...  2023-03-21T11:00:05Z
# ...

# %%
df.info() #mnampilkan info dari tabel
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         506 non-null    object
#  1   published_at  506 non-null    object
#  2   duration      506 non-null    object
#  3   view_count    506 non-null    object
# dtypes: object(4)
# memory usage: 15.9+ KB

# %%
df.describe() #menampilkan deskripsi tabel
# Out:
#                                                     title  \
# count                                                 506
# unique                                                503
# top     BTS (방탄소년단) 'Yet To Come (The Most Beautiful M...
# freq                                                    2
#
#                 published_at duration     view_count
# count                    506      506            506
# unique                   502      353            501
# top     2023-02-09T13:40:00Z    PT16S  No View Count
# freq                       2       19              3

# %%
df.groupby(["duration"]).size() #mengelompokkan kolom
# Out:
# duration
# PT10M13S    1
# PT10M18S    1
# PT10M29S    1
# PT10M31S    1
# PT10M43S    1
#            ..
# PT9M2S      1
# PT9M36S     2
# PT9M37S     1
# PT9M44S     1
# PT9M58S     1
# Length: 353, dtype: int64

# %%
//Kesimpulan dari data diatas yaitu saya menganalisa lagu-lagu BTS ada 4 kolom dengan jumlah 505
baris.Tidak ada duration yang sama antara lagu satu dengan lagu yang lain.
Lagu yang paling top yaitu Yet To Come. Lagu yang terletak paling
atas yaitu lagu dari Jungkook yang berjudul 3D.

Cara untuk menganalisisnya yaitu yang pertama import data.csv. lalu muncul seluruh data. untuk
menampilkan data dari atas yaitu dengan df.head(jumlah data yg ingin ditampilkan). Untuk menampilkan
data dari yang paling bawah yaitu dengan df.tail(jumlah data yg ingin di tampilkan). lalu untuk
menampilkan data dari berapa ke berapa yaitu dengan df.[20:30]. lalu untuk menampilkan info
seluruh tabel yaitu dengan df.info(). setelah itu untuk menunjukkan deskripsi yaitu dengan
df.describe(). Yang terakhir yaitu untuk mencari tau salah satu kolom dari tabel.
